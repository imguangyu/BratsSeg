# %% [markdown]
# # Inspect the dataset

# %%
import numpy as np

# %%
train = np.load('brats_112/train.npz', allow_pickle=True)

# %%
imgs = train['images']
labels = train['labels']

# %% [markdown]
# Modalities: ['flair', 't1', 't2']
#
# classes:
# -           0: Background
# -           1: Necrotic and non-enhancing tumor core
# -           2: Peritumoral edema
# -           3: Enhancing tumor

# %%
import matplotlib.pyplot as plt

example = imgs.item()['flair'][0]
label = labels[0]

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(example, cmap='gray')
plt.title('Flair Image')
plt.subplot(1, 2, 2)
plt.imshow(label, cmap='gray')
plt.title('Label')
plt.show()

# %% [markdown]
# # Generate pngs

# %%
from brats import BraTS

modality = 'flair'

dataset = BraTS(data_dir='brats_112', split='train', modality=modality)

# %%
plt.imshow(dataset[0][0], cmap='gray')
plt.show()
